# %%
import requests
from bs4 import BeautifulSoup

# %%
def scraper():
    url = "https://www.utahcounty.gov/landrecords/SerialVersions.asp?av_serial=01:002:0001"
    response = requests.get(url)

# %%
url = "https://www.utahcounty.gov/landrecords/property.asp?av_serial=10020001010"
response = requests.get(url)

# %%
response
# Out:
# <Response [403]>

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# <hr/><center>nginx/1.19.3</center>
# </body>
# </html>

# %%
url2 = "https://apps.uintah.utah.gov/ords/ucdev/r/public-searches/property-search"
response = requests.get(url2)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js page-3 app-PUBLIC-SEARCHES" lang="en">
# <head>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta charset="utf-8"/>
# <title>Uintah County Property Search</title>
# <base href="/ords/"/>
# <link href="/i/libraries/oraclejet/10.0.0/css/libs/oj/v10.0.0/redwood/oj-redwood-notag-min.css?v=21.1.5" rel="stylesheet" type="text/css"/>
# <link href="/i/app_ui/css/Core.min.css?v=21.1.5" rel="stylesheet" type="text/css"/>
# <link href="/i/app_ui/css/Theme-Standard.min.css?v=21.1.5" rel="stylesheet" type="text/css"/>
# <link href="/i/libraries/font-apex/2.2/css/font-apex.min.css?v=21.1.5" rel="stylesheet" type="text/css"/>
# <link href="/i/themes/theme_42/1.5/css/Core.min.css?v=21.1.5" rel="stylesheet" type="text/css"/>
# <link href="ucdev/r/147/files/theme/42/v66/24726301913754546.css" rel="stylesheet" type="text/css"/>
# <link href="ucdev/r/147/files/static/v17/app-icon.css?version=Release%201.0" rel="stylesheet" type="text/css"/>
# ...
